# %%
# All libraries & Data points
import jetset
print('tested on jetset',jetset.__version__)
import warnings
warnings.filterwarnings('ignore')
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from jetset.data_loader import Data
from jetset.data_loader import ObsData
from jetset.plot_sedfit import PlotSED
from jetset.jet_model import Jet
from jetset.minimizer import fit_SED,ModelMinimizer
from jetset.model_manager import  FitModel
from jetset.sed_shaper import  SEDShape
from jetset.obs_constrain import ObsConstrain
from jetset.minimizer import fit_SED
from jetset.template_2Dmodel import EBLAbsorptionTemplate
from jetset.mcmc import McmcSampler

ebl_franceschini=EBLAbsorptionTemplate.from_name('Franceschini_2008')
sed_data=ObsData.load('J163547_data.pkl')
plt.rcParams.update({'font.size': 14})
plt.rcParams['figure.dpi'] = 200
plt.rcParams["savefig.bbox"] = 'tight'
# Out:
# tested on jetset 1.2.2

# %%
model=FitModel.load_model("fit_model_5_1.pkl")

model.add_component(ebl_franceschini)

model.link_par(par_name='z_cosm',
                      from_model='Franceschini_2008',
                      to_model='jet_leptonic')

model.composite_expr='(jet_leptonic)*Franceschini_2008'

model.eval()
#model.save_model('EBL5.pkl')
#model.show_model()
p2=model.plot_model(sed_data=sed_data)
legend_labels = [r'$\eta=0.057$', 'Sync', 'SSC', 'EC Disc', 'Disc', 'EC DT', 'DT','EC BLR', 'EBL Corrections', 'Data']
p2.sedplot.legend(labels = legend_labels, loc='upper left', fontsize=12)
p2.sedplot.grid(False)
p2.setlim(x_min=1e7,x_max=4e26,y_min=1.0e-16,y_max=1e-11)
p2.save('img_EBL/EBL5.png')
# Out:
# ==> par R_DT is now depending on ['L_Disk'] according to expr:R_DT =
# 2E19*(L_Disk/1E46)**0.5
# ==> par R_BLR_in is now depending on ['L_Disk'] according to expr:R_BLR_in =
# 3E17*(L_Disk/1E46)**0.5
# ==> par R_BLR_out is now depending on ['R_BLR_in'] according to expr:R_BLR_out =
# R_BLR_in*1.1
# ==> par R is now depending on ['R_H', 'theta_open'] according to expr:R =
# np.tan((theta_open*np.pi/180))*R_H
# ==> par: z_cosm from model: Franceschini_2008 linked to same parameter in model jet_leptonic

# %%
model=FitModel.load_model("/home/chema/Desktop/Astro&Cosmo/Thesis/JetSET/PrePrefit_A/PrePre_model_2.pkl")

model.add_component(ebl_franceschini)

model.composite_expr='(jet_leptonic)*Franceschini_2008'

model.eval()
#model.save_model('EBL8.pkl')
#model.show_model()
p2=model.plot_model(sed_data=sed_data)
legend_labels = [r'$\eta=0.083$', 'Sync', 'SSC', 'EC Disc', 'Disc', 'EC DT', 'DT','EC BLR', 'EBL Corrections', 'Data']
p2.sedplot.legend(labels = legend_labels, loc='upper left', fontsize=12)
p2.sedplot.grid(False)
p2.setlim(x_min=1e7,x_max=4e26,y_min=1.0e-16,y_max=1e-11)
p2.save('img_EBL/EBL8.png')
# Out:
# ==> par R_DT is now depending on ['L_Disk'] according to expr:R_DT =
# 2E19*(L_Disk/1E46)**0.5
# ==> par R_BLR_in is now depending on ['L_Disk'] according to expr:R_BLR_in =
# 3E17*(L_Disk/1E46)**0.5
# ==> par R_BLR_out is now depending on ['R_BLR_in'] according to expr:R_BLR_out =
# R_BLR_in*1.1
# ==> par R is now depending on ['R_H', 'theta_open'] according to expr:R =
# np.tan((theta_open*np.pi/180))*R_H

# %%
model=FitModel.load_model("fit_model_1_2.pkl")

model.add_component(ebl_franceschini)

model.composite_expr='(jet_leptonic)*Franceschini_2008'

model.eval()
#model.save_model('EBL1.pkl')
#model.show_model()
p2=model.plot_model(sed_data=sed_data)
legend_labels = [r'$\eta=0.100$', 'Sync', 'SSC', 'EC Disc', 'Disc', 'EC DT', 'DT','EC BLR', 'EBL Corrections', 'Data']
p2.sedplot.legend(labels = legend_labels, loc='upper left', fontsize=12)
p2.sedplot.grid(False)
p2.setlim(x_min=1e7,x_max=4e26,y_min=1.0e-16,y_max=1e-11)
p2.save('img_EBL/EBL1.png')
# Out:
# ==> par R_DT is now depending on ['L_Disk'] according to expr:R_DT =
# 2E19*(L_Disk/1E46)**0.5
# ==> par R_BLR_in is now depending on ['L_Disk'] according to expr:R_BLR_in =
# 3E17*(L_Disk/1E46)**0.5
# ==> par R_BLR_out is now depending on ['R_BLR_in'] according to expr:R_BLR_out =
# R_BLR_in*1.1
# ==> par R is now depending on ['R_H', 'theta_open'] according to expr:R =
# np.tan((theta_open*np.pi/180))*R_H

# %%
model=FitModel.load_model("fit_model_1_5_2.pkl")

model.add_component(ebl_franceschini)

model.composite_expr='(jet_leptonic)*Franceschini_2008'

model.eval()
#model.save_model('EBL15.pkl')
#model.show_model()
p2=model.plot_model(sed_data=sed_data)
legend_labels = [r'$\eta=0.150$', 'Sync', 'SSC', 'EC Disc', 'Disc', 'EC DT', 'DT','EC BLR', 'EBL Corrections', 'Data']
p2.sedplot.legend(labels = legend_labels, loc='upper left', fontsize=12)
p2.sedplot.grid(False)
p2.setlim(x_min=1e7,x_max=4e26,y_min=1.0e-16,y_max=1e-11)
p2.save('img_EBL/EBL15.png')
# Out:
# ==> par R_DT is now depending on ['L_Disk'] according to expr:R_DT =
# 2E19*(L_Disk/1E46)**0.5
# ==> par R_BLR_in is now depending on ['L_Disk'] according to expr:R_BLR_in =
# 3E17*(L_Disk/1E46)**0.5
# ==> par R_BLR_out is now depending on ['R_BLR_in'] according to expr:R_BLR_out =
# R_BLR_in*1.1
# ==> par R is now depending on ['R_H', 'theta_open'] according to expr:R =
# np.tan((theta_open*np.pi/180))*R_H

# %%
model=FitModel.load_model("fit_model_2_2.pkl")

model.add_component(ebl_franceschini)

model.composite_expr='(jet_leptonic)*Franceschini_2008'

model.eval()
#model.save_model('EBL2.pkl')
#model.show_model()
p2=model.plot_model(sed_data=sed_data)
legend_labels = [r'$\eta=0.200$', 'Sync', 'SSC', 'EC Disc', 'Disc', 'EC DT', 'DT','EC BLR', 'EBL Corrections', 'Data']
p2.sedplot.legend(labels = legend_labels, loc='upper left', fontsize=12)
p2.sedplot.grid(False)
p2.setlim(x_min=1e7,x_max=4e26,y_min=1.0e-16,y_max=1e-11)
p2.save('img_EBL/EBL2.png')
# Out:
# ==> par R_DT is now depending on ['L_Disk'] according to expr:R_DT =
# 2E19*(L_Disk/1E46)**0.5
# ==> par R_BLR_in is now depending on ['L_Disk'] according to expr:R_BLR_in =
# 3E17*(L_Disk/1E46)**0.5
# ==> par R_BLR_out is now depending on ['R_BLR_in'] according to expr:R_BLR_out =
# R_BLR_in*1.1
# ==> par R is now depending on ['R_H', 'theta_open'] according to expr:R =
# np.tan((theta_open*np.pi/180))*R_H

# %%
model=FitModel.load_model("fit_model_3_2.pkl")

model.add_component(ebl_franceschini)

model.composite_expr='(jet_leptonic)*Franceschini_2008'

model.eval()
#model.save_model('EBL3.pkl')
#model.show_model()
p2=model.plot_model(sed_data=sed_data)
legend_labels = [r'$\eta=0.300$', 'Sync', 'SSC', 'EC Disc', 'Disc', 'EC DT', 'DT','EC BLR', 'EBL Corrections', 'Data']
p2.sedplot.legend(labels = legend_labels, loc='upper left', fontsize=12)
p2.sedplot.grid(False)
p2.setlim(x_min=1e7,x_max=4e26,y_min=1.0e-16,y_max=1e-11)
p2.save('img_EBL/EBL3.png')
# Out:
# ==> par R_DT is now depending on ['L_Disk'] according to expr:R_DT =
# 2E19*(L_Disk/1E46)**0.5
# ==> par R_BLR_in is now depending on ['L_Disk'] according to expr:R_BLR_in =
# 3E17*(L_Disk/1E46)**0.5
# ==> par R_BLR_out is now depending on ['R_BLR_in'] according to expr:R_BLR_out =
# R_BLR_in*1.1
# ==> par R is now depending on ['R_H', 'theta_open'] according to expr:R =
# np.tan((theta_open*np.pi/180))*R_H
